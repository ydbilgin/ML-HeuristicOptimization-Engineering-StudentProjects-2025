# %%
# !python vrp/geocode_addresses.py --depots-file vrp/addresses/istanbul_depots.txt \
  --customers-file vrp/addresses/istanbul_customers.txt \
  --base-url http://localhost:7070 --out-dir data/geocoded --prefix istanbul

# %%
# %run vrp/run_vrp.py --depots-csv data/geocoded/istanbul_depots.csv \
  --customers-csv data/geocoded/istanbul_customers.csv \
  --vehicles 4 --pop-size 1000 --generations 5000 \
  --distance-mode osrm --osrm-base-url http://localhost:5000 \
  --out out/istanbul_routes.json \
  --export-points data/geocoded/istanbul_points.csv \
  --plot-html out/istanbul_map.html --plot-km-chart out/istanbul_km.png
# Out:
# Toplam km: 248.993
# Toplam sure: 411.5 dk (~6.86 saat)
#
# Depo D1 icin rotalar:
#   Rota 1: 37.9 km, 75.6 dk, 24 musteri
#   Rota 2: 58.2 km, 117.2 dk, 24 musteri
#   Rota 3: 54.9 km, 85.7 dk, 24 musteri
#   Rota 4: 97.9 km, 133.0 dk, 23 musteri
# Cikti: out\istanbul_routes.json
# Harita kaydedildi: out\istanbul_map.html
# KM grafigi kaydedildi: out\istanbul_km.png

# %%
# %run vrp/plot_report.py --routes-json out/istanbul_routes.json \
  --points-csv data/geocoded/istanbul_points.csv \
  --map-html out/istanbul_map.html --km-chart out/istanbul_km.png \
  --inline
# Out:
# KM grafiği kaydedildi: out\istanbul_km.png
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
